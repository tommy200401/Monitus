# %%
import nltk
import json
import re
import pandas as pd
from bs4 import BeautifulSoup
import os
from urllib.request import urlopen

# %%
response = urlopen('https://financialmodelingprep.com/api/v3/income-statement/AAPL?period=quarter&limit=400&apikey=f33b3631d5140a4f1c87e7f2eafd8fdd')
data=response.read().decode('utf-8')
income=json.loads(data)
df = pd.DataFrame(income)

# %%
df
# Out:
#            date symbol reportedCurrency          fillingDate  \
# 0    2021-03-27   AAPL              USD           2021-04-29
# 1    2020-12-26   AAPL              USD           2021-01-28
# 2    2020-09-26   AAPL              USD           2020-10-30
# 3    2020-06-27   AAPL              USD           2020-07-31
# 4    2020-03-28   AAPL              USD  2020-05-01 00:00:00
# ..          ...    ...              ...                  ...
# 129  1987-03-31   AAPL              USD           1987-03-31
# 130  1986-12-31   AAPL              USD           1986-12-31
# 131  1986-06-30   AAPL              USD           1986-06-30
# 132  1986-03-31   AAPL              USD           1986-03-31
# 133  1985-12-31   AAPL              USD           1985-12-31
#
#             acceptedDate period       revenue  costOfRevenue   grossProfit  \
# 0    2021-04-28 18:02:54     Q2   89584000000   5.150500e+10  3.807900e+10
# 1    2021-01-27 18:03:06     Q1  111439000000   6.711100e+10  4.432800e+10
# ...

# %%
df[df['grossProfit']==0]
# Out:
#            date symbol reportedCurrency fillingDate acceptedDate period  \
# 122  1989-06-30   AAPL              USD  1989-06-30   1989-06-30     Q3
# 123  1989-03-31   AAPL              USD  1989-03-31   1989-03-31     Q2
# 124  1988-12-31   AAPL              USD  1988-12-31   1988-12-31     Q1
# 125  1988-06-30   AAPL              USD  1988-06-30   1988-06-30     Q3
# 126  1988-03-31   AAPL              USD  1988-03-31   1988-03-31     Q2
# 127  1987-12-31   AAPL              USD  1987-12-31   1987-12-31     Q1
# 128  1987-06-30   AAPL              USD  1987-06-30   1987-06-30     Q3
# 129  1987-03-31   AAPL              USD  1987-03-31   1987-03-31     Q2
# 130  1986-12-31   AAPL              USD  1986-12-31   1986-12-31     Q1
# 131  1986-06-30   AAPL              USD  1986-06-30   1986-06-30     Q3
# 132  1986-03-31   AAPL              USD  1986-03-31   1986-03-31     Q2
# 133  1985-12-31   AAPL              USD  1985-12-31   1985-12-31     Q1
#
# ...

# %%
response = urlopen('https://financialmodelingprep.com/api/v3/balance-sheet-statement/AAPL?period=quarter&limit=400&apikey=f33b3631d5140a4f1c87e7f2eafd8fdd')
data=response.read().decode('utf-8')
asset=json.loads(data)
df = pd.DataFrame(asset)
df
# Out:
#            date symbol reportedCurrency fillingDate         acceptedDate  \
# 0    2021-03-27   AAPL              USD  2021-04-29  2021-04-28 18:02:54
# 1    2020-12-26   AAPL              USD  2021-01-28  2021-01-27 18:03:06
# 2    2020-09-26   AAPL              USD  2020-10-30  2020-10-29 18:06:25
# 3    2020-06-27   AAPL              USD  2020-07-31  2020-07-30 19:29:09
# 4    2020-03-28   AAPL              USD  2020-05-01  2020-04-30 18:03:10
# ..          ...    ...              ...         ...                  ...
# 126  1989-09-30   AAPL              USD  1989-09-30           1989-09-30
# 127  1988-09-30   AAPL              USD  1988-09-30           1988-09-30
# 128  1987-09-30   AAPL              USD  1987-09-30           1987-09-30
# 129  1986-09-30   AAPL              USD  1986-09-30           1986-09-30
# 130  1985-09-30   AAPL              USD  1985-09-30           1985-09-30
#
#     period  cashAndCashEquivalents  shortTermInvestments  \
# ...
